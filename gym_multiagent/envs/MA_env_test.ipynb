# %%
from bokeh.io import output_notebook, show, push_notebook
from bokeh.plotting import figure
from bokeh.layouts import gridplot
import numpy as np
import random
import time

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1c3dda00-4b14-4308-a661-6fc8bfe9f7dc">Loading BokehJS ...</span>
#     </div>

# %%
min_screen_x, min_screen_y, max_screen_x, max_screen_y, me_x, me_y, target_x, target_y = \
            0, 0, 200, 200, 20, 20, 50, 60
plt_loc = figure(
    plot_width=600,
    plot_height=600,
    toolbar_location=None,
    x_range=(min_screen_x-30, max_screen_x+30),
    y_range=(max_screen_y+30, min_screen_y-30),
    x_axis_location="above",
    title="敌我距离")  # use up-left corner as origin
plt_loc.title.align = "center"
plt_loc.title.text_color = "orange"
plt_loc.title.text_font_size = "25px"
plt_loc.title.background_fill_color = "blue"

rd_loc = plt_loc.circle(
            [me_x, target_x], [me_y, target_y],
            size=20,
            line_color="gold",
            fill_color=["green", "firebrick"],
            fill_alpha=0.6)

# %%
location = {
    'me_x': 1,
    'me_y': 2,
    'target_x': 2,
    'target_y':3
}
me_speed = 5
target_speed=15

def calc_eucl_dist(pos1, pos2):
    # calc Euclidean Distance
    _coords1 = np.array(pos1)  # location of me
    _coords2 = np.array(pos2)
    # alternative way: np.linalg.norm(_coords1 - _coords2)
    eucl_dist = np.sqrt(np.sum((_coords1 - _coords2)**2))
    return eucl_dist

def refresh_render(location):
    eucl_dist = calc_eucl_dist((location['target_x'], location['target_y']), (location['me_x'], location['me_y']) )
    plt_loc.title.text = "敌我距离: {:12.2f}".format(eucl_dist)
    # plt_loc.x_range.start = location["min_screen_x"]
    # plt_loc.x_range.end = location["max_screen_x"]
    # plt_loc.y_range.start = location["max_screen_y"]
    # plt_loc.y_range.end = location["min_screen_y"]
    rd_loc.data_source.data['x'] = [
        location['me_x'], location['target_x']
    ]
    rd_loc.data_source.data['y'] = [
        location['me_y'], location['target_y']
    ]

    push_notebook()  # self.nb_handle

def step(location):
    final_decision = location.copy()
    
    # the target will run out of me as far as possible
    # 要么走x， 要么走y，先看边界，再选距离， 上下左右
    npc = (location['target_x'], location['target_y'])
    player = (location['me_x'], location['me_y'])
    npc_new_loc = action_by_one_side(npc, player, target_speed, mode="run")
    
    final_decision['target_x'], final_decision['target_y'] = npc_new_loc
    
    # samely, for me, run to get more close to target
    player_new_loc = action_by_one_side(player, npc_new_loc, me_speed, mode="catch")
    final_decision['me_x'], final_decision['me_y'] = player_new_loc
    
    
    return final_decision

def action_by_one_side(my_pos, adversary_pos, my_speed, mode="run"):  
    """mode can be run/catch"""
    x, y = my_pos
    available_direction = [
        y - my_speed > min_screen_y,
        y + my_speed < max_screen_y,
        x - my_speed > min_screen_x,
        x + my_speed < max_screen_x,
    ]
    new_location = [
        (x, y - my_speed),
        (x, y + my_speed),
        (x - my_speed, y),
        (x + my_speed, y),
    ]
    
    available_loc = [_l for i, _l in enumerate(new_location) if available_direction[i]]
    
    new_dist = [calc_eucl_dist(my_new_pos, adversary_pos) for my_new_pos in available_loc]
    
    func = max if mode =="run" else min
    best_choice = func(enumerate(new_dist), key=lambda x: x[1])[0]
    my_final_pos = available_loc[best_choice]
    return my_final_pos

# %%
nb_handle = show(plt_loc, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d931cfab-977e-43e9-bc5b-f3ab65c03a6d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d931cfab-977e-43e9-bc5b-f3ab65c03a6d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("224a0702-8d90-4210-8dc0-8dab99fc68db", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d931cfab-977e-43e9-bc5b-f3ab65c03a6d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd931cfab-977e-43e9-bc5b-f3ab65c03a6d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"91b4ebdd-a0b2-4ba8-8836-b381dba7a7f9":{"roots":{"references":[{"attributes":{"plot":{"id":"396cfb25-f7b0-4c2c-be27-e39dec6998d8","subtype":"Figure","type":"Plot"}},"id":"02d4c51b-1bc4-45a7-adbd-d20845a7e4b4","type":"PanTool"},{"attributes":{"formatter":{"id":"030d9ea4-74b1-4622-b199-e841f3610bce","type":"BasicTickFormatter"},"plot":{"id":"396cfb25-f7b0-4c2c-be27-e39dec6998d8","subtype":"Figure","type":"Plot"},"ticker":{"id":"11d613e5-520f-4d32-b9b2-fad9640c9ac3","type":"BasicTicker"}},"id":"d63e1929-2361-4737-a5fa-2a51e0bcee49","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f99e4cb8-2d4d-4653-a48b-992d9d552419","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"f99e4cb8-2d4d-4653-a48b-992d9d552419","type":"BoxAnnotation"},"plot":{"id":"396cfb25-f7b0-4c2c-be27-e39dec6998d8","subtype":"Figure","type":"Plot"}},"id":"63846064-deae-4d8b-88ec-62dcf3fcf712","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"396cfb25-f7b0-4c2c-be27-e39dec6998d8","subtype":"Figure","type":"Plot"},"ticker":{"id":"c3467d69-dcdf-492f-bd10-65bdcb20d2bd","type":"BasicTicker"}},"id":"8a835849-410c-4478-9350-d2cea120d589","type":"Grid"},{"attributes":{"above":[{"id":"d63e1929-2361-4737-a5fa-2a51e0bcee49","type":"LinearAxis"}],"left":[{"id":"fe023c44-1f43-429d-b845-57bd370dd800","type":"LinearAxis"}],"renderers":[{"id":"d63e1929-2361-4737-a5fa-2a51e0bcee49","type":"LinearAxis"},{"id":"6b8b2b96-948b-4e67-a39c-9ed93978cad8","type":"Grid"},{"id":"fe023c44-1f43-429d-b845-57bd370dd800","type":"LinearAxis"},{"id":"8a835849-410c-4478-9350-d2cea120d589","type":"Grid"},{"id":"f99e4cb8-2d4d-4653-a48b-992d9d552419","type":"BoxAnnotation"},{"id":"0281c197-7a0c-4223-ae24-3b3549142a12","type":"GlyphRenderer"}],"title":{"id":"3d446340-b3f6-4b41-b2a0-525ada17ad51","type":"Title"},"tool_events":{"id":"abdc7d0e-5338-4c78-8133-d7ed1d7e2c9a","type":"ToolEvents"},"toolbar":{"id":"ed149d99-6638-4db0-b89f-86e0f7957cd3","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"b1bd5dce-b661-4ac3-8926-df64d9288ed1","type":"Range1d"},"x_scale":{"id":"10626990-b17e-41a4-a52d-a7c1c5d66b61","type":"LinearScale"},"y_range":{"id":"a2188e38-5218-44be-b734-b24ee5401159","type":"Range1d"},"y_scale":{"id":"371aa364-13cf-445e-802d-e4d46e640342","type":"LinearScale"}},"id":"396cfb25-f7b0-4c2c-be27-e39dec6998d8","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":230,"start":-30},"id":"b1bd5dce-b661-4ac3-8926-df64d9288ed1","type":"Range1d"},{"attributes":{"plot":{"id":"396cfb25-f7b0-4c2c-be27-e39dec6998d8","subtype":"Figure","type":"Plot"}},"id":"5e121c72-6171-4165-a581-e8c70c07dbe3","type":"ResetTool"},{"attributes":{"plot":{"id":"396cfb25-f7b0-4c2c-be27-e39dec6998d8","subtype":"Figure","type":"Plot"}},"id":"795514fa-3236-45ae-85c2-d37d152f6b9d","type":"SaveTool"},{"attributes":{},"id":"10626990-b17e-41a4-a52d-a7c1c5d66b61","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"02d4c51b-1bc4-45a7-adbd-d20845a7e4b4","type":"PanTool"},{"id":"c6e1358d-88c5-4358-ada5-683bacfb860c","type":"WheelZoomTool"},{"id":"63846064-deae-4d8b-88ec-62dcf3fcf712","type":"BoxZoomTool"},{"id":"795514fa-3236-45ae-85c2-d37d152f6b9d","type":"SaveTool"},{"id":"5e121c72-6171-4165-a581-e8c70c07dbe3","type":"ResetTool"},{"id":"7b00dc7e-e9df-481c-9303-4fdfbd8484d8","type":"HelpTool"}]},"id":"ed149d99-6638-4db0-b89f-86e0f7957cd3","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["y","x","fill_color"],"data":{"fill_color":["green","firebrick"],"x":[20,50],"y":[20,60]}},"id":"c9b0b705-4236-4ccf-9f1f-16ed35a69c4a","type":"ColumnDataSource"},{"attributes":{"align":"cent ...

# %%
# 把代码放到图下面运行， 看起来方便一点
new_loc = location
for i in range(500):
    new_loc = step(new_loc)
    print(new_loc)

    refresh_render(new_loc)
    time.sleep(0.02)
# Out:
# {'target_y': 18, 'target_x': 2, 'me_y': 7, 'me_x': 1}
# {'target_y': 33, 'target_x': 2, 'me_y': 12, 'me_x': 1}
# {'target_y': 48, 'target_x': 2, 'me_y': 17, 'me_x': 1}
# {'target_y': 63, 'target_x': 2, 'me_y': 22, 'me_x': 1}
# {'target_y': 78, 'target_x': 2, 'me_y': 27, 'me_x': 1}
# {'target_y': 93, 'target_x': 2, 'me_y': 32, 'me_x': 1}
# {'target_y': 108, 'target_x': 2, 'me_y': 37, 'me_x': 1}
# {'target_y': 123, 'target_x': 2, 'me_y': 42, 'me_x': 1}
# {'target_y': 138, 'target_x': 2, 'me_y': 47, 'me_x': 1}
# {'target_y': 153, 'target_x': 2, 'me_y': 52, 'me_x': 1}
# {'target_y': 168, 'target_x': 2, 'me_y': 57, 'me_x': 1}
# {'target_y': 183, 'target_x': 2, 'me_y': 62, 'me_x': 1}
# {'target_y': 198, 'target_x': 2, 'me_y': 67, 'me_x': 1}
# {'target_y': 198, 'target_x': 17, 'me_y': 72, 'me_x': 1}
# {'target_y': 198, 'target_x': 32, 'me_y': 77, 'me_x': 1}
# {'target_y': 198, 'target_x': 47, 'me_y': 82, 'me_x': 1}
# {'target_y': 198, 'target_x': 62, 'me_y': 87, 'me_x': 1}
# {'target_y': 198, 'target_x': 77, 'me_y': 92, 'me_x': 1}
# {'target_y': 198, 'target_x': 92, 'me_y': 97, 'me_x': 1}
# {'target_y': 198, 'target_x': 107, 'me_y': 97, 'me_x': 6}
# {'target_y': 198, 'target_x': 122, 'me_y': 97, 'me_x': 11}
# {'target_y': 198, 'target_x': 137, 'me_y': 97, 'me_x': 16}
# {'target_y': 198, 'target_x': 152, 'me_y': 97, 'me_x': 21}
# {'target_y': 198, 'target_x': 167, 'me_y': 97, 'me_x': 26}
# {'target_y': 198, 'target_x': 182, 'me_y': 97, 'me_x': 31}
# {'target_y': 198, 'target_x': 197, 'me_y': 97, 'me_x': 36}
# {'target_y': 183, 'target_x': 197, 'me_y': 97, 'me_x': 41}
# {'target_y': 198, 'target_x': 197, 'me_y': 97, 'me_x': 46}
# {'target_y': 183, 'target_x': 197, 'me_y': 97, 'me_x': 51}
# {'target_y': 198, 'target_x': 197, 'me_y': 97, 'me_x': 56}
# {'target_y': 183, 'target_x': 197, 'me_y': 97, 'me_x': 61}
# {'target_y': 198, 'target_x': 197, 'me_y': 97, 'me_x': 66}
# {'target_y': 183, 'target_x': 197, 'me_y': 97, 'me_x': 71}
# {'target_y': 198, 'target_x': 197, 'me_y': 97, 'me_x': 76}
# {'target_y': 183, 'target_x': 197, 'me_y': 97, 'me_x': 81}
# {'target_y': 198, 'target_x': 197, 'me_y': 97, 'me_x': 86}
# {'target_y': 183, 'target_x': 197, 'me_y': 97, 'me_x': 91}
# {'target_y': 198, 'target_x': 197, 'me_y': 97, 'me_x': 96}
# {'target_y': 183, 'target_x': 197, 'me_y': 97, 'me_x': 101}
# {'target_y': 198, 'target_x': 197, 'me_y': 102, 'me_x': 101}
# {'target_y': 183, 'target_x': 197, 'me_y': 102, 'me_x': 106}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 106}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 111}
# {'target_y': 198, 'target_x': 197, 'me_y': 112, 'me_x': 111}
# {'target_y': 183, 'target_x': 197, 'me_y': 112, 'me_x': 116}
# {'target_y': 198, 'target_x': 197, 'me_y': 117, 'me_x': 116}
# {'target_y': 183, 'target_x': 197, 'me_y': 117, 'me_x': 121}
# {'target_y': 198, 'target_x': 197, 'me_y': 122, 'me_x': 121}
# {'target_y': 183, 'target_x': 197, 'me_y': 122, 'me_x': 126}
# {'target_y': 198, 'target_x': 197, 'me_y': 127, 'me_x': 126}
# {'target_y': 183, 'target_x': 197, 'me_y': 127, 'me_x': 131}
# {'target_y': 198, 'target_x': 197, 'me_y': 132, 'me_x': 131}
# {'target_y': 183, 'target_x': 197, 'me_y': 132, 'me_x': 136}
# {'target_y': 198, 'target_x': 197, 'me_y': 137, 'me_x': 136}
# {'target_y': 183, 'target_x': 197, 'me_y': 137, 'me_x': 141}
# {'target_y': 198, 'target_x': 197, 'me_y': 142, 'me_x': 141}
# {'target_y': 183, 'target_x': 197, 'me_y': 142, 'me_x': 146}
# {'target_y': 198, 'target_x': 197, 'me_y': 147, 'me_x': 146}
# {'target_y': 183, 'target_x': 197, 'me_y': 147, 'me_x': 151}
# {'target_y': 198, 'target_x': 197, 'me_y': 152, 'me_x': 151}
# {'target_y': 183, 'target_x': 197, 'me_y': 152, 'me_x': 156}
# {'target_y': 198, 'target_x': 197, 'me_y': 157, 'me_x': 156}
# {'target_y': 183, 'target_x': 197, 'me_y': 157, 'me_x': 161}
# {'target_y': 198, 'target_x': 197, 'me_y': 162, 'me_x': 161}
# {'target_y': 183, 'target_x': 197, 'me_y': 162, 'me_x': 166}
# {'target_y': 198, 'target_x': 197, 'me_y': 167, 'me_x': 166}
# {'target_y': 183, 'target_x': 197, 'me_y': 167, 'me_x': 171}
# {'target_y': 198, 'target_x': 197, 'me_y': 172, 'me_x': 171}
# {'target_y': 183, 'target_x': 197, 'me_y': 172, 'me_x': 176}
# {'target_y': 198, 'target_x': 197, 'me_y': 177, 'me_x': 176}
# {'target_y': 183, 'target_x': 197, 'me_y': 177, 'me_x': 181}
# {'target_y': 198, 'target_x': 197, 'me_y': 182, 'me_x': 181}
# {'target_y': 183, 'target_x': 197, 'me_y': 182, 'me_x': 186}
# {'target_y': 198, 'target_x': 197, 'me_y': 187, 'me_x': 186}
# {'target_y': 183, 'target_x': 197, 'me_y': 187, 'me_x': 191}
# {'target_y': 168, 'target_x': 197, 'me_y': 182, 'me_x': 191}
# {'target_y': 153, 'target_x': 197, 'me_y': 177, 'me_x': 191}
# {'target_y': 138, 'target_x': 197, 'me_y': 172, 'me_x': 191}
# {'target_y': 123, 'target_x': 197, 'me_y': 167, 'me_x': 191}
# {'target_y': 108, 'target_x': 197, 'me_y': 162, 'me_x': 191}
# {'target_y': 93, 'target_x': 197, 'me_y': 157, 'me_x': 191}
# {'target_y': 78, 'target_x': 197, 'me_y': 152, 'me_x': 191}
# {'target_y': 63, 'target_x': 197, 'me_y': 147, 'me_x': 191}
# {'target_y': 48, 'target_x': 197, 'me_y': 142, 'me_x': 191}
# {'target_y': 33, 'target_x': 197, 'me_y': 137, 'me_x': 191}
# {'target_y': 18, 'target_x': 197, 'me_y': 132, 'me_x': 191}
# {'target_y': 3, 'target_x': 197, 'me_y': 127, 'me_x': 191}
# {'target_y': 3, 'target_x': 182, 'me_y': 122, 'me_x': 191}
# {'target_y': 3, 'target_x': 167, 'me_y': 117, 'me_x': 191}
# {'target_y': 3, 'target_x': 152, 'me_y': 112, 'me_x': 191}
# {'target_y': 3, 'target_x': 137, 'me_y': 107, 'me_x': 191}
# {'target_y': 3, 'target_x': 122, 'me_y': 102, 'me_x': 191}
# {'target_y': 3, 'target_x': 107, 'me_y': 97, 'me_x': 191}
# {'target_y': 3, 'target_x': 92, 'me_y': 97, 'me_x': 186}
# {'target_y': 3, 'target_x': 77, 'me_y': 97, 'me_x': 181}
# {'target_y': 3, 'target_x': 62, 'me_y': 97, 'me_x': 176}
# {'target_y': 3, 'target_x': 47, 'me_y': 97, 'me_x': 171}
# {'target_y': 3, 'target_x': 32, 'me_y': 97, 'me_x': 166}
# {'target_y': 3, 'target_x': 17, 'me_y': 97, 'me_x': 161}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 156}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 151}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 146}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 141}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 136}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 131}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 126}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 121}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 116}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 111}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 106}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 101}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 96}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 91}
# {'target_y': 3, 'target_x': 2, 'me_y': 92, 'me_x': 91}
# {'target_y': 18, 'target_x': 2, 'me_y': 92, 'me_x': 86}
# {'target_y': 3, 'target_x': 2, 'me_y': 87, 'me_x': 86}
# {'target_y': 18, 'target_x': 2, 'me_y': 87, 'me_x': 81}
# {'target_y': 3, 'target_x': 2, 'me_y': 82, 'me_x': 81}
# {'target_y': 18, 'target_x': 2, 'me_y': 82, 'me_x': 76}
# {'target_y': 3, 'target_x': 2, 'me_y': 77, 'me_x': 76}
# {'target_y': 18, 'target_x': 2, 'me_y': 77, 'me_x': 71}
# {'target_y': 3, 'target_x': 2, 'me_y': 72, 'me_x': 71}
# {'target_y': 18, 'target_x': 2, 'me_y': 72, 'me_x': 66}
# {'target_y': 3, 'target_x': 2, 'me_y': 67, 'me_x': 66}
# {'target_y': 18, 'target_x': 2, 'me_y': 67, 'me_x': 61}
# {'target_y': 3, 'target_x': 2, 'me_y': 62, 'me_x': 61}
# {'target_y': 18, 'target_x': 2, 'me_y': 62, 'me_x': 56}
# {'target_y': 3, 'target_x': 2, 'me_y': 57, 'me_x': 56}
# {'target_y': 18, 'target_x': 2, 'me_y': 57, 'me_x': 51}
# {'target_y': 3, 'target_x': 2, 'me_y': 52, 'me_x': 51}
# {'target_y': 18, 'target_x': 2, 'me_y': 52, 'me_x': 46}
# {'target_y': 3, 'target_x': 2, 'me_y': 47, 'me_x': 46}
# {'target_y': 18, 'target_x': 2, 'me_y': 47, 'me_x': 41}
# {'target_y': 3, 'target_x': 2, 'me_y': 42, 'me_x': 41}
# {'target_y': 18, 'target_x': 2, 'me_y': 42, 'me_x': 36}
# {'target_y': 3, 'target_x': 2, 'me_y': 37, 'me_x': 36}
# {'target_y': 18, 'target_x': 2, 'me_y': 37, 'me_x': 31}
# {'target_y': 3, 'target_x': 2, 'me_y': 32, 'me_x': 31}
# {'target_y': 18, 'target_x': 2, 'me_y': 32, 'me_x': 26}
# {'target_y': 3, 'target_x': 2, 'me_y': 27, 'me_x': 26}
# {'target_y': 18, 'target_x': 2, 'me_y': 27, 'me_x': 21}
# {'target_y': 3, 'target_x': 2, 'me_y': 22, 'me_x': 21}
# {'target_y': 18, 'target_x': 2, 'me_y': 22, 'me_x': 16}
# {'target_y': 3, 'target_x': 2, 'me_y': 17, 'me_x': 16}
# {'target_y': 18, 'target_x': 2, 'me_y': 17, 'me_x': 11}
# {'target_y': 33, 'target_x': 2, 'me_y': 22, 'me_x': 11}
# {'target_y': 48, 'target_x': 2, 'me_y': 27, 'me_x': 11}
# {'target_y': 63, 'target_x': 2, 'me_y': 32, 'me_x': 11}
# {'target_y': 78, 'target_x': 2, 'me_y': 37, 'me_x': 11}
# {'target_y': 93, 'target_x': 2, 'me_y': 42, 'me_x': 11}
# {'target_y': 108, 'target_x': 2, 'me_y': 47, 'me_x': 11}
# {'target_y': 123, 'target_x': 2, 'me_y': 52, 'me_x': 11}
# {'target_y': 138, 'target_x': 2, 'me_y': 57, 'me_x': 11}
# {'target_y': 153, 'target_x': 2, 'me_y': 62, 'me_x': 11}
# {'target_y': 168, 'target_x': 2, 'me_y': 67, 'me_x': 11}
# {'target_y': 183, 'target_x': 2, 'me_y': 72, 'me_x': 11}
# {'target_y': 198, 'target_x': 2, 'me_y': 77, 'me_x': 11}
# {'target_y': 198, 'target_x': 17, 'me_y': 82, 'me_x': 11}
# {'target_y': 198, 'target_x': 32, 'me_y': 87, 'me_x': 11}
# {'target_y': 198, 'target_x': 47, 'me_y': 92, 'me_x': 11}
# {'target_y': 198, 'target_x': 62, 'me_y': 97, 'me_x': 11}
# {'target_y': 198, 'target_x': 77, 'me_y': 102, 'me_x': 11}
# {'target_y': 198, 'target_x': 92, 'me_y': 107, 'me_x': 11}
# {'target_y': 198, 'target_x': 107, 'me_y': 107, 'me_x': 16}
# {'target_y': 198, 'target_x': 122, 'me_y': 107, 'me_x': 21}
# {'target_y': 198, 'target_x': 137, 'me_y': 107, 'me_x': 26}
# {'target_y': 198, 'target_x': 152, 'me_y': 107, 'me_x': 31}
# {'target_y': 198, 'target_x': 167, 'me_y': 107, 'me_x': 36}
# {'target_y': 198, 'target_x': 182, 'me_y': 107, 'me_x': 41}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 46}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 51}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 56}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 61}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 66}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 71}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 76}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 81}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 86}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 91}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 96}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 101}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 106}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 111}
# {'target_y': 198, 'target_x': 197, 'me_y': 112, 'me_x': 111}
# {'target_y': 183, 'target_x': 197, 'me_y': 112, 'me_x': 116}
# {'target_y': 198, 'target_x': 197, 'me_y': 117, 'me_x': 116}
# {'target_y': 183, 'target_x': 197, 'me_y': 117, 'me_x': 121}
# {'target_y': 198, 'target_x': 197, 'me_y': 122, 'me_x': 121}
# {'target_y': 183, 'target_x': 197, 'me_y': 122, 'me_x': 126}
# {'target_y': 198, 'target_x': 197, 'me_y': 127, 'me_x': 126}
# {'target_y': 183, 'target_x': 197, 'me_y': 127, 'me_x': 131}
# {'target_y': 198, 'target_x': 197, 'me_y': 132, 'me_x': 131}
# {'target_y': 183, 'target_x': 197, 'me_y': 132, 'me_x': 136}
# {'target_y': 198, 'target_x': 197, 'me_y': 137, 'me_x': 136}
# {'target_y': 183, 'target_x': 197, 'me_y': 137, 'me_x': 141}
# {'target_y': 198, 'target_x': 197, 'me_y': 142, 'me_x': 141}
# {'target_y': 183, 'target_x': 197, 'me_y': 142, 'me_x': 146}
# {'target_y': 198, 'target_x': 197, 'me_y': 147, 'me_x': 146}
# {'target_y': 183, 'target_x': 197, 'me_y': 147, 'me_x': 151}
# {'target_y': 198, 'target_x': 197, 'me_y': 152, 'me_x': 151}
# {'target_y': 183, 'target_x': 197, 'me_y': 152, 'me_x': 156}
# {'target_y': 198, 'target_x': 197, 'me_y': 157, 'me_x': 156}
# {'target_y': 183, 'target_x': 197, 'me_y': 157, 'me_x': 161}
# {'target_y': 198, 'target_x': 197, 'me_y': 162, 'me_x': 161}
# {'target_y': 183, 'target_x': 197, 'me_y': 162, 'me_x': 166}
# {'target_y': 198, 'target_x': 197, 'me_y': 167, 'me_x': 166}
# {'target_y': 183, 'target_x': 197, 'me_y': 167, 'me_x': 171}
# {'target_y': 198, 'target_x': 197, 'me_y': 172, 'me_x': 171}
# {'target_y': 183, 'target_x': 197, 'me_y': 172, 'me_x': 176}
# {'target_y': 198, 'target_x': 197, 'me_y': 177, 'me_x': 176}
# {'target_y': 183, 'target_x': 197, 'me_y': 177, 'me_x': 181}
# {'target_y': 198, 'target_x': 197, 'me_y': 182, 'me_x': 181}
# {'target_y': 183, 'target_x': 197, 'me_y': 182, 'me_x': 186}
# {'target_y': 198, 'target_x': 197, 'me_y': 187, 'me_x': 186}
# {'target_y': 183, 'target_x': 197, 'me_y': 187, 'me_x': 191}
# {'target_y': 168, 'target_x': 197, 'me_y': 182, 'me_x': 191}
# {'target_y': 153, 'target_x': 197, 'me_y': 177, 'me_x': 191}
# {'target_y': 138, 'target_x': 197, 'me_y': 172, 'me_x': 191}
# {'target_y': 123, 'target_x': 197, 'me_y': 167, 'me_x': 191}
# {'target_y': 108, 'target_x': 197, 'me_y': 162, 'me_x': 191}
# {'target_y': 93, 'target_x': 197, 'me_y': 157, 'me_x': 191}
# {'target_y': 78, 'target_x': 197, 'me_y': 152, 'me_x': 191}
# {'target_y': 63, 'target_x': 197, 'me_y': 147, 'me_x': 191}
# {'target_y': 48, 'target_x': 197, 'me_y': 142, 'me_x': 191}
# {'target_y': 33, 'target_x': 197, 'me_y': 137, 'me_x': 191}
# {'target_y': 18, 'target_x': 197, 'me_y': 132, 'me_x': 191}
# {'target_y': 3, 'target_x': 197, 'me_y': 127, 'me_x': 191}
# {'target_y': 3, 'target_x': 182, 'me_y': 122, 'me_x': 191}
# {'target_y': 3, 'target_x': 167, 'me_y': 117, 'me_x': 191}
# {'target_y': 3, 'target_x': 152, 'me_y': 112, 'me_x': 191}
# {'target_y': 3, 'target_x': 137, 'me_y': 107, 'me_x': 191}
# {'target_y': 3, 'target_x': 122, 'me_y': 102, 'me_x': 191}
# {'target_y': 3, 'target_x': 107, 'me_y': 97, 'me_x': 191}
# {'target_y': 3, 'target_x': 92, 'me_y': 97, 'me_x': 186}
# {'target_y': 3, 'target_x': 77, 'me_y': 97, 'me_x': 181}
# {'target_y': 3, 'target_x': 62, 'me_y': 97, 'me_x': 176}
# {'target_y': 3, 'target_x': 47, 'me_y': 97, 'me_x': 171}
# {'target_y': 3, 'target_x': 32, 'me_y': 97, 'me_x': 166}
# {'target_y': 3, 'target_x': 17, 'me_y': 97, 'me_x': 161}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 156}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 151}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 146}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 141}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 136}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 131}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 126}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 121}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 116}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 111}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 106}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 101}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 96}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 91}
# {'target_y': 3, 'target_x': 2, 'me_y': 92, 'me_x': 91}
# {'target_y': 18, 'target_x': 2, 'me_y': 92, 'me_x': 86}
# {'target_y': 3, 'target_x': 2, 'me_y': 87, 'me_x': 86}
# {'target_y': 18, 'target_x': 2, 'me_y': 87, 'me_x': 81}
# {'target_y': 3, 'target_x': 2, 'me_y': 82, 'me_x': 81}
# {'target_y': 18, 'target_x': 2, 'me_y': 82, 'me_x': 76}
# {'target_y': 3, 'target_x': 2, 'me_y': 77, 'me_x': 76}
# {'target_y': 18, 'target_x': 2, 'me_y': 77, 'me_x': 71}
# {'target_y': 3, 'target_x': 2, 'me_y': 72, 'me_x': 71}
# {'target_y': 18, 'target_x': 2, 'me_y': 72, 'me_x': 66}
# {'target_y': 3, 'target_x': 2, 'me_y': 67, 'me_x': 66}
# {'target_y': 18, 'target_x': 2, 'me_y': 67, 'me_x': 61}
# {'target_y': 3, 'target_x': 2, 'me_y': 62, 'me_x': 61}
# {'target_y': 18, 'target_x': 2, 'me_y': 62, 'me_x': 56}
# {'target_y': 3, 'target_x': 2, 'me_y': 57, 'me_x': 56}
# {'target_y': 18, 'target_x': 2, 'me_y': 57, 'me_x': 51}
# {'target_y': 3, 'target_x': 2, 'me_y': 52, 'me_x': 51}
# {'target_y': 18, 'target_x': 2, 'me_y': 52, 'me_x': 46}
# {'target_y': 3, 'target_x': 2, 'me_y': 47, 'me_x': 46}
# {'target_y': 18, 'target_x': 2, 'me_y': 47, 'me_x': 41}
# {'target_y': 3, 'target_x': 2, 'me_y': 42, 'me_x': 41}
# {'target_y': 18, 'target_x': 2, 'me_y': 42, 'me_x': 36}
# {'target_y': 3, 'target_x': 2, 'me_y': 37, 'me_x': 36}
# {'target_y': 18, 'target_x': 2, 'me_y': 37, 'me_x': 31}
# {'target_y': 3, 'target_x': 2, 'me_y': 32, 'me_x': 31}
# {'target_y': 18, 'target_x': 2, 'me_y': 32, 'me_x': 26}
# {'target_y': 3, 'target_x': 2, 'me_y': 27, 'me_x': 26}
# {'target_y': 18, 'target_x': 2, 'me_y': 27, 'me_x': 21}
# {'target_y': 3, 'target_x': 2, 'me_y': 22, 'me_x': 21}
# {'target_y': 18, 'target_x': 2, 'me_y': 22, 'me_x': 16}
# {'target_y': 3, 'target_x': 2, 'me_y': 17, 'me_x': 16}
# {'target_y': 18, 'target_x': 2, 'me_y': 17, 'me_x': 11}
# {'target_y': 33, 'target_x': 2, 'me_y': 22, 'me_x': 11}
# {'target_y': 48, 'target_x': 2, 'me_y': 27, 'me_x': 11}
# {'target_y': 63, 'target_x': 2, 'me_y': 32, 'me_x': 11}
# {'target_y': 78, 'target_x': 2, 'me_y': 37, 'me_x': 11}
# {'target_y': 93, 'target_x': 2, 'me_y': 42, 'me_x': 11}
# {'target_y': 108, 'target_x': 2, 'me_y': 47, 'me_x': 11}
# {'target_y': 123, 'target_x': 2, 'me_y': 52, 'me_x': 11}
# {'target_y': 138, 'target_x': 2, 'me_y': 57, 'me_x': 11}
# {'target_y': 153, 'target_x': 2, 'me_y': 62, 'me_x': 11}
# {'target_y': 168, 'target_x': 2, 'me_y': 67, 'me_x': 11}
# {'target_y': 183, 'target_x': 2, 'me_y': 72, 'me_x': 11}
# {'target_y': 198, 'target_x': 2, 'me_y': 77, 'me_x': 11}
# {'target_y': 198, 'target_x': 17, 'me_y': 82, 'me_x': 11}
# {'target_y': 198, 'target_x': 32, 'me_y': 87, 'me_x': 11}
# {'target_y': 198, 'target_x': 47, 'me_y': 92, 'me_x': 11}
# {'target_y': 198, 'target_x': 62, 'me_y': 97, 'me_x': 11}
# {'target_y': 198, 'target_x': 77, 'me_y': 102, 'me_x': 11}
# {'target_y': 198, 'target_x': 92, 'me_y': 107, 'me_x': 11}
# {'target_y': 198, 'target_x': 107, 'me_y': 107, 'me_x': 16}
# {'target_y': 198, 'target_x': 122, 'me_y': 107, 'me_x': 21}
# {'target_y': 198, 'target_x': 137, 'me_y': 107, 'me_x': 26}
# {'target_y': 198, 'target_x': 152, 'me_y': 107, 'me_x': 31}
# {'target_y': 198, 'target_x': 167, 'me_y': 107, 'me_x': 36}
# {'target_y': 198, 'target_x': 182, 'me_y': 107, 'me_x': 41}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 46}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 51}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 56}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 61}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 66}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 71}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 76}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 81}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 86}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 91}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 96}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 101}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 106}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 111}
# {'target_y': 198, 'target_x': 197, 'me_y': 112, 'me_x': 111}
# {'target_y': 183, 'target_x': 197, 'me_y': 112, 'me_x': 116}
# {'target_y': 198, 'target_x': 197, 'me_y': 117, 'me_x': 116}
# {'target_y': 183, 'target_x': 197, 'me_y': 117, 'me_x': 121}
# {'target_y': 198, 'target_x': 197, 'me_y': 122, 'me_x': 121}
# {'target_y': 183, 'target_x': 197, 'me_y': 122, 'me_x': 126}
# {'target_y': 198, 'target_x': 197, 'me_y': 127, 'me_x': 126}
# {'target_y': 183, 'target_x': 197, 'me_y': 127, 'me_x': 131}
# {'target_y': 198, 'target_x': 197, 'me_y': 132, 'me_x': 131}
# {'target_y': 183, 'target_x': 197, 'me_y': 132, 'me_x': 136}
# {'target_y': 198, 'target_x': 197, 'me_y': 137, 'me_x': 136}
# {'target_y': 183, 'target_x': 197, 'me_y': 137, 'me_x': 141}
# {'target_y': 198, 'target_x': 197, 'me_y': 142, 'me_x': 141}
# {'target_y': 183, 'target_x': 197, 'me_y': 142, 'me_x': 146}
# {'target_y': 198, 'target_x': 197, 'me_y': 147, 'me_x': 146}
# {'target_y': 183, 'target_x': 197, 'me_y': 147, 'me_x': 151}
# {'target_y': 198, 'target_x': 197, 'me_y': 152, 'me_x': 151}
# {'target_y': 183, 'target_x': 197, 'me_y': 152, 'me_x': 156}
# {'target_y': 198, 'target_x': 197, 'me_y': 157, 'me_x': 156}
# {'target_y': 183, 'target_x': 197, 'me_y': 157, 'me_x': 161}
# {'target_y': 198, 'target_x': 197, 'me_y': 162, 'me_x': 161}
# {'target_y': 183, 'target_x': 197, 'me_y': 162, 'me_x': 166}
# {'target_y': 198, 'target_x': 197, 'me_y': 167, 'me_x': 166}
# {'target_y': 183, 'target_x': 197, 'me_y': 167, 'me_x': 171}
# {'target_y': 198, 'target_x': 197, 'me_y': 172, 'me_x': 171}
# {'target_y': 183, 'target_x': 197, 'me_y': 172, 'me_x': 176}
# {'target_y': 198, 'target_x': 197, 'me_y': 177, 'me_x': 176}
# {'target_y': 183, 'target_x': 197, 'me_y': 177, 'me_x': 181}
# {'target_y': 198, 'target_x': 197, 'me_y': 182, 'me_x': 181}
# {'target_y': 183, 'target_x': 197, 'me_y': 182, 'me_x': 186}
# {'target_y': 198, 'target_x': 197, 'me_y': 187, 'me_x': 186}
# {'target_y': 183, 'target_x': 197, 'me_y': 187, 'me_x': 191}
# {'target_y': 168, 'target_x': 197, 'me_y': 182, 'me_x': 191}
# {'target_y': 153, 'target_x': 197, 'me_y': 177, 'me_x': 191}
# {'target_y': 138, 'target_x': 197, 'me_y': 172, 'me_x': 191}
# {'target_y': 123, 'target_x': 197, 'me_y': 167, 'me_x': 191}
# {'target_y': 108, 'target_x': 197, 'me_y': 162, 'me_x': 191}
# {'target_y': 93, 'target_x': 197, 'me_y': 157, 'me_x': 191}
# {'target_y': 78, 'target_x': 197, 'me_y': 152, 'me_x': 191}
# {'target_y': 63, 'target_x': 197, 'me_y': 147, 'me_x': 191}
# {'target_y': 48, 'target_x': 197, 'me_y': 142, 'me_x': 191}
# {'target_y': 33, 'target_x': 197, 'me_y': 137, 'me_x': 191}
# {'target_y': 18, 'target_x': 197, 'me_y': 132, 'me_x': 191}
# {'target_y': 3, 'target_x': 197, 'me_y': 127, 'me_x': 191}
# {'target_y': 3, 'target_x': 182, 'me_y': 122, 'me_x': 191}
# {'target_y': 3, 'target_x': 167, 'me_y': 117, 'me_x': 191}
# {'target_y': 3, 'target_x': 152, 'me_y': 112, 'me_x': 191}
# {'target_y': 3, 'target_x': 137, 'me_y': 107, 'me_x': 191}
# {'target_y': 3, 'target_x': 122, 'me_y': 102, 'me_x': 191}
# {'target_y': 3, 'target_x': 107, 'me_y': 97, 'me_x': 191}
# {'target_y': 3, 'target_x': 92, 'me_y': 97, 'me_x': 186}
# {'target_y': 3, 'target_x': 77, 'me_y': 97, 'me_x': 181}
# {'target_y': 3, 'target_x': 62, 'me_y': 97, 'me_x': 176}
# {'target_y': 3, 'target_x': 47, 'me_y': 97, 'me_x': 171}
# {'target_y': 3, 'target_x': 32, 'me_y': 97, 'me_x': 166}
# {'target_y': 3, 'target_x': 17, 'me_y': 97, 'me_x': 161}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 156}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 151}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 146}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 141}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 136}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 131}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 126}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 121}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 116}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 111}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 106}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 101}
# {'target_y': 3, 'target_x': 2, 'me_y': 97, 'me_x': 96}
# {'target_y': 18, 'target_x': 2, 'me_y': 97, 'me_x': 91}
# {'target_y': 3, 'target_x': 2, 'me_y': 92, 'me_x': 91}
# {'target_y': 18, 'target_x': 2, 'me_y': 92, 'me_x': 86}
# {'target_y': 3, 'target_x': 2, 'me_y': 87, 'me_x': 86}
# {'target_y': 18, 'target_x': 2, 'me_y': 87, 'me_x': 81}
# {'target_y': 3, 'target_x': 2, 'me_y': 82, 'me_x': 81}
# {'target_y': 18, 'target_x': 2, 'me_y': 82, 'me_x': 76}
# {'target_y': 3, 'target_x': 2, 'me_y': 77, 'me_x': 76}
# {'target_y': 18, 'target_x': 2, 'me_y': 77, 'me_x': 71}
# {'target_y': 3, 'target_x': 2, 'me_y': 72, 'me_x': 71}
# {'target_y': 18, 'target_x': 2, 'me_y': 72, 'me_x': 66}
# {'target_y': 3, 'target_x': 2, 'me_y': 67, 'me_x': 66}
# {'target_y': 18, 'target_x': 2, 'me_y': 67, 'me_x': 61}
# {'target_y': 3, 'target_x': 2, 'me_y': 62, 'me_x': 61}
# {'target_y': 18, 'target_x': 2, 'me_y': 62, 'me_x': 56}
# {'target_y': 3, 'target_x': 2, 'me_y': 57, 'me_x': 56}
# {'target_y': 18, 'target_x': 2, 'me_y': 57, 'me_x': 51}
# {'target_y': 3, 'target_x': 2, 'me_y': 52, 'me_x': 51}
# {'target_y': 18, 'target_x': 2, 'me_y': 52, 'me_x': 46}
# {'target_y': 3, 'target_x': 2, 'me_y': 47, 'me_x': 46}
# {'target_y': 18, 'target_x': 2, 'me_y': 47, 'me_x': 41}
# {'target_y': 3, 'target_x': 2, 'me_y': 42, 'me_x': 41}
# {'target_y': 18, 'target_x': 2, 'me_y': 42, 'me_x': 36}
# {'target_y': 3, 'target_x': 2, 'me_y': 37, 'me_x': 36}
# {'target_y': 18, 'target_x': 2, 'me_y': 37, 'me_x': 31}
# {'target_y': 3, 'target_x': 2, 'me_y': 32, 'me_x': 31}
# {'target_y': 18, 'target_x': 2, 'me_y': 32, 'me_x': 26}
# {'target_y': 3, 'target_x': 2, 'me_y': 27, 'me_x': 26}
# {'target_y': 18, 'target_x': 2, 'me_y': 27, 'me_x': 21}
# {'target_y': 3, 'target_x': 2, 'me_y': 22, 'me_x': 21}
# {'target_y': 18, 'target_x': 2, 'me_y': 22, 'me_x': 16}
# {'target_y': 3, 'target_x': 2, 'me_y': 17, 'me_x': 16}
# {'target_y': 18, 'target_x': 2, 'me_y': 17, 'me_x': 11}
# {'target_y': 33, 'target_x': 2, 'me_y': 22, 'me_x': 11}
# {'target_y': 48, 'target_x': 2, 'me_y': 27, 'me_x': 11}
# {'target_y': 63, 'target_x': 2, 'me_y': 32, 'me_x': 11}
# {'target_y': 78, 'target_x': 2, 'me_y': 37, 'me_x': 11}
# {'target_y': 93, 'target_x': 2, 'me_y': 42, 'me_x': 11}
# {'target_y': 108, 'target_x': 2, 'me_y': 47, 'me_x': 11}
# {'target_y': 123, 'target_x': 2, 'me_y': 52, 'me_x': 11}
# {'target_y': 138, 'target_x': 2, 'me_y': 57, 'me_x': 11}
# {'target_y': 153, 'target_x': 2, 'me_y': 62, 'me_x': 11}
# {'target_y': 168, 'target_x': 2, 'me_y': 67, 'me_x': 11}
# {'target_y': 183, 'target_x': 2, 'me_y': 72, 'me_x': 11}
# {'target_y': 198, 'target_x': 2, 'me_y': 77, 'me_x': 11}
# {'target_y': 198, 'target_x': 17, 'me_y': 82, 'me_x': 11}
# {'target_y': 198, 'target_x': 32, 'me_y': 87, 'me_x': 11}
# {'target_y': 198, 'target_x': 47, 'me_y': 92, 'me_x': 11}
# {'target_y': 198, 'target_x': 62, 'me_y': 97, 'me_x': 11}
# {'target_y': 198, 'target_x': 77, 'me_y': 102, 'me_x': 11}
# {'target_y': 198, 'target_x': 92, 'me_y': 107, 'me_x': 11}
# {'target_y': 198, 'target_x': 107, 'me_y': 107, 'me_x': 16}
# {'target_y': 198, 'target_x': 122, 'me_y': 107, 'me_x': 21}
# {'target_y': 198, 'target_x': 137, 'me_y': 107, 'me_x': 26}
# {'target_y': 198, 'target_x': 152, 'me_y': 107, 'me_x': 31}
# {'target_y': 198, 'target_x': 167, 'me_y': 107, 'me_x': 36}
# {'target_y': 198, 'target_x': 182, 'me_y': 107, 'me_x': 41}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 46}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 51}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 56}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 61}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 66}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 71}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 76}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 81}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 86}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 91}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 96}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 101}
# {'target_y': 198, 'target_x': 197, 'me_y': 107, 'me_x': 106}
# {'target_y': 183, 'target_x': 197, 'me_y': 107, 'me_x': 111}
# {'target_y': 198, 'target_x': 197, 'me_y': 112, 'me_x': 111}
# {'target_y': 183, 'target_x': 197, 'me_y': 112, 'me_x': 116}
# {'target_y': 198, 'target_x': 197, 'me_y': 117, 'me_x': 116}
# {'target_y': 183, 'target_x': 197, 'me_y': 117, 'me_x': 121}
# {'target_y': 198, 'target_x': 197, 'me_y': 122, 'me_x': 121}
# {'target_y': 183, 'target_x': 197, 'me_y': 122, 'me_x': 126}
# {'target_y': 198, 'target_x': 197, 'me_y': 127, 'me_x': 126}
# {'target_y': 183, 'target_x': 197, 'me_y': 127, 'me_x': 131}
# {'target_y': 198, 'target_x': 197, 'me_y': 132, 'me_x': 131}
# {'target_y': 183, 'target_x': 197, 'me_y': 132, 'me_x': 136}
# {'target_y': 198, 'target_x': 197, 'me_y': 137, 'me_x': 136}
# {'target_y': 183, 'target_x': 197, 'me_y': 137, 'me_x': 141}
# {'target_y': 198, 'target_x': 197, 'me_y': 142, 'me_x': 141}
# {'target_y': 183, 'target_x': 197, 'me_y': 142, 'me_x': 146}
# {'target_y': 198, 'target_x': 197, 'me_y': 147, 'me_x': 146}
# {'target_y': 183, 'target_x': 197, 'me_y': 147, 'me_x': 151}
# {'target_y': 198, 'target_x': 197, 'me_y': 152, 'me_x': 151}
# {'target_y': 183, 'target_x': 197, 'me_y': 152, 'me_x': 156}
# {'target_y': 198, 'target_x': 197, 'me_y': 157, 'me_x': 156}
# {'target_y': 183, 'target_x': 197, 'me_y': 157, 'me_x': 161}
# {'target_y': 198, 'target_x': 197, 'me_y': 162, 'me_x': 161}
# {'target_y': 183, 'target_x': 197, 'me_y': 162, 'me_x': 166}
# {'target_y': 198, 'target_x': 197, 'me_y': 167, 'me_x': 166}
# {'target_y': 183, 'target_x': 197, 'me_y': 167, 'me_x': 171}
# {'target_y': 198, 'target_x': 197, 'me_y': 172, 'me_x': 171}
# {'target_y': 183, 'target_x': 197, 'me_y': 172, 'me_x': 176}
# {'target_y': 198, 'target_x': 197, 'me_y': 177, 'me_x': 176}
# {'target_y': 183, 'target_x': 197, 'me_y': 177, 'me_x': 181}
# {'target_y': 198, 'target_x': 197, 'me_y': 182, 'me_x': 181}
# {'target_y': 183, 'target_x': 197, 'me_y': 182, 'me_x': 186}
# {'target_y': 198, 'target_x': 197, 'me_y': 187, 'me_x': 186}
# {'target_y': 183, 'target_x': 197, 'me_y': 187, 'me_x': 191}
# {'target_y': 168, 'target_x': 197, 'me_y': 182, 'me_x': 191}
# {'target_y': 153, 'target_x': 197, 'me_y': 177, 'me_x': 191}
# {'target_y': 138, 'target_x': 197, 'me_y': 172, 'me_x': 191}
# {'target_y': 123, 'target_x': 197, 'me_y': 167, 'me_x': 191}
# {'target_y': 108, 'target_x': 197, 'me_y': 162, 'me_x': 191}
