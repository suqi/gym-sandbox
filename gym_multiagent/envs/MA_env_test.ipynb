# %%
from bokeh.io import output_notebook, show, push_notebook
from bokeh.plotting import figure
from bokeh.layouts import gridplot
import numpy as np
import random
import time

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8f150eac-a98b-4c98-90a7-fb12faf7a3a7">Loading BokehJS ...</span>
#     </div>

# %%
min_screen_x, min_screen_y, max_screen_x, max_screen_y, me_x, me_y, target_x, target_y = \
            0, 0, 200, 200, 20, 20, 50, 60
plt_loc = figure(
    plot_width=600,
    plot_height=600,
    toolbar_location=None,
    x_range=(min_screen_x-30, max_screen_x+30),
    y_range=(max_screen_y+30, min_screen_y-30),
    x_axis_location="above",
    title="敌我距离")  # use up-left corner as origin
plt_loc.title.align = "center"
plt_loc.title.text_color = "orange"
plt_loc.title.text_font_size = "25px"
plt_loc.title.background_fill_color = "blue"

rd_loc = plt_loc.circle(
            [me_x, target_x], [me_y, target_y],
            size=[50, 20],
            line_color="gold",
            line_width=[10, 1],
            fill_color=["green", "yellow"],
            fill_alpha=0.6)

# %%
location = {
    'me_x': 1,
    'me_y': 2,
    'target_x': 2,
    'target_y':3
}
me_speed = 5
target_speed=15

def calc_eucl_dist(pos1, pos2):
    # calc Euclidean Distance
    _coords1 = np.array(pos1)  # location of me
    _coords2 = np.array(pos2)
    # alternative way: np.linalg.norm(_coords1 - _coords2)
    eucl_dist = np.sqrt(np.sum((_coords1 - _coords2)**2))
    return eucl_dist

def refresh_render(location):
    eucl_dist = calc_eucl_dist((location['target_x'], location['target_y']), (location['me_x'], location['me_y']) )
    plt_loc.title.text = "敌我距离: {:12.2f}".format(eucl_dist)
    # plt_loc.x_range.start = location["min_screen_x"]
    # plt_loc.x_range.end = location["max_screen_x"]
    # plt_loc.y_range.start = location["max_screen_y"]
    # plt_loc.y_range.end = location["min_screen_y"]
    rd_loc.data_source.data['x'] = [
        location['me_x'], location['target_x']
    ]
    rd_loc.data_source.data['y'] = [
        location['me_y'], location['target_y']
    ]
    
    if eucl_dist < 100:
        rd_loc.data_source.data['fill_color']  = ["green", "red"]
    else:
        rd_loc.data_source.data['fill_color']  = ["green", "yellow"]

    push_notebook()  # self.nb_handle

def step(location):
    final_decision = location.copy()
    
    # the target will run out of me as far as possible
    # 要么走x， 要么走y，先看边界，再选距离， 上下左右
    npc = (location['target_x'], location['target_y'])
    player = (location['me_x'], location['me_y'])
    npc_new_loc = action_by_one_side(npc, player, target_speed, mode="run")
    
    final_decision['target_x'], final_decision['target_y'] = npc_new_loc
    
    # samely, for me, run to get more close to target
    player_new_loc = action_by_one_side(player, npc_new_loc, me_speed, mode="catch")
    final_decision['me_x'], final_decision['me_y'] = player_new_loc
    
    
    return final_decision

def action_by_one_side(my_pos, adversary_pos, my_speed, mode="run"):  
    """mode can be run/catch"""
    x, y = my_pos
    available_direction = [
        y - my_speed > min_screen_y,
        y + my_speed < max_screen_y,
        x - my_speed > min_screen_x,
        x + my_speed < max_screen_x,
    ]
    new_location = [
        (x, y - my_speed),
        (x, y + my_speed),
        (x - my_speed, y),
        (x + my_speed, y),
    ]
    
    available_loc = [_l for i, _l in enumerate(new_location) if available_direction[i]]
    
    new_dist = [calc_eucl_dist(my_new_pos, adversary_pos) for my_new_pos in available_loc]
    
    func = max if mode =="run" else min
    best_choice = func(enumerate(new_dist), key=lambda x: x[1])[0]
    my_final_pos = available_loc[best_choice]
    return my_final_pos

# %%
nb_handle = show(plt_loc, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cd254666-610d-4bdb-9cad-7fdd5f4d1a78"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cd254666-610d-4bdb-9cad-7fdd5f4d1a78");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("863e3675-b756-492c-aff9-57342fa5fbbe", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd254666-610d-4bdb-9cad-7fdd5f4d1a78");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd254666-610d-4bdb-9cad-7fdd5f4d1a78' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"84a352a6-8cf6-4fb4-a736-87df4f207c17":{"roots":{"references":[{"attributes":{"plot":{"id":"ba49a5f8-2f9f-41c5-bdaf-14cce8bb6c6b","subtype":"Figure","type":"Plot"}},"id":"22c09bac-35fb-4384-9bda-daeb8082a69f","type":"PanTool"},{"attributes":{},"id":"3382434a-3634-4843-8a9b-2a0370a29772","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f273a40f-ac70-466f-af6d-cf24d4ce14a8","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":-30,"start":230},"id":"7372cc39-5eda-4839-a6bf-02b221d3534b","type":"Range1d"},{"attributes":{"above":[{"id":"f6a12a61-28e5-4848-89ff-32ab599aab46","type":"LinearAxis"}],"left":[{"id":"402b25fc-5cba-46c3-9b54-643dc75e2569","type":"LinearAxis"}],"renderers":[{"id":"f6a12a61-28e5-4848-89ff-32ab599aab46","type":"LinearAxis"},{"id":"8429f951-b09e-46c1-8de8-697599187c0c","type":"Grid"},{"id":"402b25fc-5cba-46c3-9b54-643dc75e2569","type":"LinearAxis"},{"id":"e8d99234-cee5-4916-94a8-8c2120fb9d96","type":"Grid"},{"id":"f273a40f-ac70-466f-af6d-cf24d4ce14a8","type":"BoxAnnotation"},{"id":"a8f372ae-6286-4acb-8897-184731ecccc2","type":"GlyphRenderer"}],"title":{"id":"6e618cd8-a8e3-4355-b50a-1182a0f6ddf4","type":"Title"},"tool_events":{"id":"8551e6d9-17a1-4583-a986-a2ae2dab50e2","type":"ToolEvents"},"toolbar":{"id":"12a904f5-7eea-4256-ba24-db988b24ccac","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"c2631b94-1f97-40f8-a3ed-884d82d3c4cf","type":"Range1d"},"x_scale":{"id":"bc2e8fa3-855d-41ef-a5b4-88f1685a635c","type":"LinearScale"},"y_range":{"id":"7372cc39-5eda-4839-a6bf-02b221d3534b","type":"Range1d"},"y_scale":{"id":"d146f21e-4f66-4102-9d75-ce3979804376","type":"LinearScale"}},"id":"ba49a5f8-2f9f-41c5-bdaf-14cce8bb6c6b","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"bc2e8fa3-855d-41ef-a5b4-88f1685a635c","type":"LinearScale"},{"attributes":{},"id":"d146f21e-4f66-4102-9d75-ce3979804376","type":"LinearScale"},{"attributes":{"overlay":{"id":"f273a40f-ac70-466f-af6d-cf24d4ce14a8","type":"BoxAnnotation"},"plot":{"id":"ba49a5f8-2f9f-41c5-bdaf-14cce8bb6c6b","subtype":"Figure","type":"Plot"}},"id":"7a1319e8-8a04-42c7-bbb2-6ad45ec977ca","type":"BoxZoomTool"},{"attributes":{},"id":"8551e6d9-17a1-4583-a986-a2ae2dab50e2","type":"ToolEvents"},{"attributes":{"plot":{"id":"ba49a5f8-2f9f-41c5-bdaf-14cce8bb6c6b","subtype":"Figure","type":"Plot"}},"id":"bdc32f4d-6f7b-497c-b28e-11473e07938b","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"6e765b84-7483-4de8-b6af-c3fa20d2be21","type":"BasicTickFormatter"},"plot":{"id":"ba49a5f8-2f9f-41c5-bdaf-14cce8bb6c6b","subtype":"Figure","type":"Plot"},"ticker":{"id":"f2774857-1175-4d13-a2dd-020027a87909","type":"BasicTicker"}},"id":"f6a12a61-28e5-4848-89ff-32ab599aab46","type":"LinearAxis"},{"attributes":{"plot":{"id":"ba49a5f8-2f9f-41c5-bdaf-14cce8bb6c6b","subtype":"Figure","type":"Plot"},"ticker":{"id":"f2774857-1175-4d13-a2dd-020027a87909","type":"BasicTicker"}},"id":"8429f951-b09e-46c1-8de8-697599187c0c","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":"gold"},"line_width":{"field":"line_width"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea5c79f6-ff0f-45c8-9905-55127e4ddec6","type":"Circle"},{"attributes":{"callback":null,"end":230,"start":-30},"id":"c2631b94-1f97-40f8-a3ed-884d82d3c4cf","type":"Range1d"},{"attributes":{"plot":{"id":"ba49a5f8-2f9f-41c5-bdaf-14cce8bb6c6b","subtype":"Figure","type":"Plot"}},"id":"7725546a-20ae-4a15-af3a-057e6b85f878","type":"ResetTool"},{"attributes":{"plot":{"id":"ba49a5f8-2f9f-41c5-bdaf-14cce8bb6c6b","subtype":"Figure","type":"Plot"}},"id":"7a4a352a-b8e5-4214-91f2-91f419120aa1","type":"SaveTo ...

# %%
# 把代码放到图下面运行， 看起来方便一点
new_loc = location
for i in range(500):
    new_loc = step(new_loc)
    print(new_loc)

    refresh_render(new_loc)
    time.sleep(0.1)
# Out:
# {'target_y': 18, 'me_x': 1, 'me_y': 7, 'target_x': 2}
# {'target_y': 33, 'me_x': 1, 'me_y': 12, 'target_x': 2}
# {'target_y': 48, 'me_x': 1, 'me_y': 17, 'target_x': 2}
# {'target_y': 63, 'me_x': 1, 'me_y': 22, 'target_x': 2}
# {'target_y': 78, 'me_x': 1, 'me_y': 27, 'target_x': 2}
# {'target_y': 93, 'me_x': 1, 'me_y': 32, 'target_x': 2}
# {'target_y': 108, 'me_x': 1, 'me_y': 37, 'target_x': 2}
# {'target_y': 123, 'me_x': 1, 'me_y': 42, 'target_x': 2}
# {'target_y': 138, 'me_x': 1, 'me_y': 47, 'target_x': 2}
# {'target_y': 153, 'me_x': 1, 'me_y': 52, 'target_x': 2}
# {'target_y': 168, 'me_x': 1, 'me_y': 57, 'target_x': 2}
# {'target_y': 183, 'me_x': 1, 'me_y': 62, 'target_x': 2}
# {'target_y': 198, 'me_x': 1, 'me_y': 67, 'target_x': 2}
# {'target_y': 198, 'me_x': 1, 'me_y': 72, 'target_x': 17}
# {'target_y': 198, 'me_x': 1, 'me_y': 77, 'target_x': 32}
# {'target_y': 198, 'me_x': 1, 'me_y': 82, 'target_x': 47}
# {'target_y': 198, 'me_x': 1, 'me_y': 87, 'target_x': 62}
# {'target_y': 198, 'me_x': 1, 'me_y': 92, 'target_x': 77}
# {'target_y': 198, 'me_x': 1, 'me_y': 97, 'target_x': 92}
# {'target_y': 198, 'me_x': 6, 'me_y': 97, 'target_x': 107}
# {'target_y': 198, 'me_x': 11, 'me_y': 97, 'target_x': 122}
# {'target_y': 198, 'me_x': 16, 'me_y': 97, 'target_x': 137}
# {'target_y': 198, 'me_x': 21, 'me_y': 97, 'target_x': 152}
# {'target_y': 198, 'me_x': 26, 'me_y': 97, 'target_x': 167}
# {'target_y': 198, 'me_x': 31, 'me_y': 97, 'target_x': 182}
# {'target_y': 198, 'me_x': 36, 'me_y': 97, 'target_x': 197}
# {'target_y': 183, 'me_x': 41, 'me_y': 97, 'target_x': 197}
# {'target_y': 198, 'me_x': 46, 'me_y': 97, 'target_x': 197}
# {'target_y': 183, 'me_x': 51, 'me_y': 97, 'target_x': 197}
# {'target_y': 198, 'me_x': 56, 'me_y': 97, 'target_x': 197}
# {'target_y': 183, 'me_x': 61, 'me_y': 97, 'target_x': 197}
# {'target_y': 198, 'me_x': 66, 'me_y': 97, 'target_x': 197}
# {'target_y': 183, 'me_x': 71, 'me_y': 97, 'target_x': 197}
# {'target_y': 198, 'me_x': 76, 'me_y': 97, 'target_x': 197}
# {'target_y': 183, 'me_x': 81, 'me_y': 97, 'target_x': 197}
# {'target_y': 198, 'me_x': 86, 'me_y': 97, 'target_x': 197}
# {'target_y': 183, 'me_x': 91, 'me_y': 97, 'target_x': 197}
# {'target_y': 198, 'me_x': 96, 'me_y': 97, 'target_x': 197}
# {'target_y': 183, 'me_x': 101, 'me_y': 97, 'target_x': 197}
# {'target_y': 198, 'me_x': 101, 'me_y': 102, 'target_x': 197}
# {'target_y': 183, 'me_x': 106, 'me_y': 102, 'target_x': 197}
# {'target_y': 198, 'me_x': 106, 'me_y': 107, 'target_x': 197}
# {'target_y': 183, 'me_x': 111, 'me_y': 107, 'target_x': 197}
# {'target_y': 198, 'me_x': 111, 'me_y': 112, 'target_x': 197}
# {'target_y': 183, 'me_x': 116, 'me_y': 112, 'target_x': 197}
# {'target_y': 198, 'me_x': 116, 'me_y': 117, 'target_x': 197}
# {'target_y': 183, 'me_x': 121, 'me_y': 117, 'target_x': 197}
# {'target_y': 198, 'me_x': 121, 'me_y': 122, 'target_x': 197}
# {'target_y': 183, 'me_x': 126, 'me_y': 122, 'target_x': 197}
# {'target_y': 198, 'me_x': 126, 'me_y': 127, 'target_x': 197}
# {'target_y': 183, 'me_x': 131, 'me_y': 127, 'target_x': 197}
# {'target_y': 198, 'me_x': 131, 'me_y': 132, 'target_x': 197}
# {'target_y': 183, 'me_x': 136, 'me_y': 132, 'target_x': 197}
# {'target_y': 198, 'me_x': 136, 'me_y': 137, 'target_x': 197}
# {'target_y': 183, 'me_x': 141, 'me_y': 137, 'target_x': 197}
# {'target_y': 198, 'me_x': 141, 'me_y': 142, 'target_x': 197}
# {'target_y': 183, 'me_x': 146, 'me_y': 142, 'target_x': 197}
# {'target_y': 198, 'me_x': 146, 'me_y': 147, 'target_x': 197}
# {'target_y': 183, 'me_x': 151, 'me_y': 147, 'target_x': 197}
# {'target_y': 198, 'me_x': 151, 'me_y': 152, 'target_x': 197}
# {'target_y': 183, 'me_x': 156, 'me_y': 152, 'target_x': 197}
# {'target_y': 198, 'me_x': 156, 'me_y': 157, 'target_x': 197}
# {'target_y': 183, 'me_x': 161, 'me_y': 157, 'target_x': 197}
# {'target_y': 198, 'me_x': 161, 'me_y': 162, 'target_x': 197}
# {'target_y': 183, 'me_x': 166, 'me_y': 162, 'target_x': 197}
# {'target_y': 198, 'me_x': 166, 'me_y': 167, 'target_x': 197}
# {'target_y': 183, 'me_x': 171, 'me_y': 167, 'target_x': 197}
# {'target_y': 198, 'me_x': 171, 'me_y': 172, 'target_x': 197}
# {'target_y': 183, 'me_x': 176, 'me_y': 172, 'target_x': 197}
# {'target_y': 198, 'me_x': 176, 'me_y': 177, 'target_x': 197}
# {'target_y': 183, 'me_x': 181, 'me_y': 177, 'target_x': 197}
# {'target_y': 198, 'me_x': 181, 'me_y': 182, 'target_x': 197}
# {'target_y': 183, 'me_x': 186, 'me_y': 182, 'target_x': 197}
# {'target_y': 198, 'me_x': 186, 'me_y': 187, 'target_x': 197}
# {'target_y': 183, 'me_x': 191, 'me_y': 187, 'target_x': 197}
# {'target_y': 168, 'me_x': 191, 'me_y': 182, 'target_x': 197}
# {'target_y': 153, 'me_x': 191, 'me_y': 177, 'target_x': 197}
# {'target_y': 138, 'me_x': 191, 'me_y': 172, 'target_x': 197}
# {'target_y': 123, 'me_x': 191, 'me_y': 167, 'target_x': 197}
# {'target_y': 108, 'me_x': 191, 'me_y': 162, 'target_x': 197}
# {'target_y': 93, 'me_x': 191, 'me_y': 157, 'target_x': 197}
# {'target_y': 78, 'me_x': 191, 'me_y': 152, 'target_x': 197}
# {'target_y': 63, 'me_x': 191, 'me_y': 147, 'target_x': 197}
# {'target_y': 48, 'me_x': 191, 'me_y': 142, 'target_x': 197}
# {'target_y': 33, 'me_x': 191, 'me_y': 137, 'target_x': 197}
# {'target_y': 18, 'me_x': 191, 'me_y': 132, 'target_x': 197}
# {'target_y': 3, 'me_x': 191, 'me_y': 127, 'target_x': 197}
# {'target_y': 3, 'me_x': 191, 'me_y': 122, 'target_x': 182}
# {'target_y': 3, 'me_x': 191, 'me_y': 117, 'target_x': 167}
# {'target_y': 3, 'me_x': 191, 'me_y': 112, 'target_x': 152}
# {'target_y': 3, 'me_x': 191, 'me_y': 107, 'target_x': 137}
# {'target_y': 3, 'me_x': 191, 'me_y': 102, 'target_x': 122}
# {'target_y': 3, 'me_x': 191, 'me_y': 97, 'target_x': 107}
# {'target_y': 3, 'me_x': 186, 'me_y': 97, 'target_x': 92}
# {'target_y': 3, 'me_x': 181, 'me_y': 97, 'target_x': 77}
# {'target_y': 3, 'me_x': 176, 'me_y': 97, 'target_x': 62}
# {'target_y': 3, 'me_x': 171, 'me_y': 97, 'target_x': 47}
# {'target_y': 3, 'me_x': 166, 'me_y': 97, 'target_x': 32}
# {'target_y': 3, 'me_x': 161, 'me_y': 97, 'target_x': 17}
# {'target_y': 3, 'me_x': 156, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 151, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 146, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 141, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 136, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 131, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 126, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 121, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 116, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 111, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 106, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 101, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 96, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 91, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 91, 'me_y': 92, 'target_x': 2}
# {'target_y': 18, 'me_x': 86, 'me_y': 92, 'target_x': 2}
# {'target_y': 3, 'me_x': 86, 'me_y': 87, 'target_x': 2}
# {'target_y': 18, 'me_x': 81, 'me_y': 87, 'target_x': 2}
# {'target_y': 3, 'me_x': 81, 'me_y': 82, 'target_x': 2}
# {'target_y': 18, 'me_x': 76, 'me_y': 82, 'target_x': 2}
# {'target_y': 3, 'me_x': 76, 'me_y': 77, 'target_x': 2}
# {'target_y': 18, 'me_x': 71, 'me_y': 77, 'target_x': 2}
# {'target_y': 3, 'me_x': 71, 'me_y': 72, 'target_x': 2}
# {'target_y': 18, 'me_x': 66, 'me_y': 72, 'target_x': 2}
# {'target_y': 3, 'me_x': 66, 'me_y': 67, 'target_x': 2}
# {'target_y': 18, 'me_x': 61, 'me_y': 67, 'target_x': 2}
# {'target_y': 3, 'me_x': 61, 'me_y': 62, 'target_x': 2}
# {'target_y': 18, 'me_x': 56, 'me_y': 62, 'target_x': 2}
# {'target_y': 3, 'me_x': 56, 'me_y': 57, 'target_x': 2}
# {'target_y': 18, 'me_x': 51, 'me_y': 57, 'target_x': 2}
# {'target_y': 3, 'me_x': 51, 'me_y': 52, 'target_x': 2}
# {'target_y': 18, 'me_x': 46, 'me_y': 52, 'target_x': 2}
# {'target_y': 3, 'me_x': 46, 'me_y': 47, 'target_x': 2}
# {'target_y': 18, 'me_x': 41, 'me_y': 47, 'target_x': 2}
# {'target_y': 3, 'me_x': 41, 'me_y': 42, 'target_x': 2}
# {'target_y': 18, 'me_x': 36, 'me_y': 42, 'target_x': 2}
# {'target_y': 3, 'me_x': 36, 'me_y': 37, 'target_x': 2}
# {'target_y': 18, 'me_x': 31, 'me_y': 37, 'target_x': 2}
# {'target_y': 3, 'me_x': 31, 'me_y': 32, 'target_x': 2}
# {'target_y': 18, 'me_x': 26, 'me_y': 32, 'target_x': 2}
# {'target_y': 3, 'me_x': 26, 'me_y': 27, 'target_x': 2}
# {'target_y': 18, 'me_x': 21, 'me_y': 27, 'target_x': 2}
# {'target_y': 3, 'me_x': 21, 'me_y': 22, 'target_x': 2}
# {'target_y': 18, 'me_x': 16, 'me_y': 22, 'target_x': 2}
# {'target_y': 3, 'me_x': 16, 'me_y': 17, 'target_x': 2}
# {'target_y': 18, 'me_x': 11, 'me_y': 17, 'target_x': 2}
# {'target_y': 33, 'me_x': 11, 'me_y': 22, 'target_x': 2}
# {'target_y': 48, 'me_x': 11, 'me_y': 27, 'target_x': 2}
# {'target_y': 63, 'me_x': 11, 'me_y': 32, 'target_x': 2}
# {'target_y': 78, 'me_x': 11, 'me_y': 37, 'target_x': 2}
# {'target_y': 93, 'me_x': 11, 'me_y': 42, 'target_x': 2}
# {'target_y': 108, 'me_x': 11, 'me_y': 47, 'target_x': 2}
# {'target_y': 123, 'me_x': 11, 'me_y': 52, 'target_x': 2}
# {'target_y': 138, 'me_x': 11, 'me_y': 57, 'target_x': 2}
# {'target_y': 153, 'me_x': 11, 'me_y': 62, 'target_x': 2}
# {'target_y': 168, 'me_x': 11, 'me_y': 67, 'target_x': 2}
# {'target_y': 183, 'me_x': 11, 'me_y': 72, 'target_x': 2}
# {'target_y': 198, 'me_x': 11, 'me_y': 77, 'target_x': 2}
# {'target_y': 198, 'me_x': 11, 'me_y': 82, 'target_x': 17}
# {'target_y': 198, 'me_x': 11, 'me_y': 87, 'target_x': 32}
# {'target_y': 198, 'me_x': 11, 'me_y': 92, 'target_x': 47}
# {'target_y': 198, 'me_x': 11, 'me_y': 97, 'target_x': 62}
# {'target_y': 198, 'me_x': 11, 'me_y': 102, 'target_x': 77}
# {'target_y': 198, 'me_x': 11, 'me_y': 107, 'target_x': 92}
# {'target_y': 198, 'me_x': 16, 'me_y': 107, 'target_x': 107}
# {'target_y': 198, 'me_x': 21, 'me_y': 107, 'target_x': 122}
# {'target_y': 198, 'me_x': 26, 'me_y': 107, 'target_x': 137}
# {'target_y': 198, 'me_x': 31, 'me_y': 107, 'target_x': 152}
# {'target_y': 198, 'me_x': 36, 'me_y': 107, 'target_x': 167}
# {'target_y': 198, 'me_x': 41, 'me_y': 107, 'target_x': 182}
# {'target_y': 198, 'me_x': 46, 'me_y': 107, 'target_x': 197}
# {'target_y': 183, 'me_x': 51, 'me_y': 107, 'target_x': 197}
# {'target_y': 198, 'me_x': 56, 'me_y': 107, 'target_x': 197}
# {'target_y': 183, 'me_x': 61, 'me_y': 107, 'target_x': 197}
# {'target_y': 198, 'me_x': 66, 'me_y': 107, 'target_x': 197}
# {'target_y': 183, 'me_x': 71, 'me_y': 107, 'target_x': 197}
# {'target_y': 198, 'me_x': 76, 'me_y': 107, 'target_x': 197}
# {'target_y': 183, 'me_x': 81, 'me_y': 107, 'target_x': 197}
# {'target_y': 198, 'me_x': 86, 'me_y': 107, 'target_x': 197}
# {'target_y': 183, 'me_x': 91, 'me_y': 107, 'target_x': 197}
# {'target_y': 198, 'me_x': 96, 'me_y': 107, 'target_x': 197}
# {'target_y': 183, 'me_x': 101, 'me_y': 107, 'target_x': 197}
# {'target_y': 198, 'me_x': 106, 'me_y': 107, 'target_x': 197}
# {'target_y': 183, 'me_x': 111, 'me_y': 107, 'target_x': 197}
# {'target_y': 198, 'me_x': 111, 'me_y': 112, 'target_x': 197}
# {'target_y': 183, 'me_x': 116, 'me_y': 112, 'target_x': 197}
# {'target_y': 198, 'me_x': 116, 'me_y': 117, 'target_x': 197}
# {'target_y': 183, 'me_x': 121, 'me_y': 117, 'target_x': 197}
# {'target_y': 198, 'me_x': 121, 'me_y': 122, 'target_x': 197}
# {'target_y': 183, 'me_x': 126, 'me_y': 122, 'target_x': 197}
# {'target_y': 198, 'me_x': 126, 'me_y': 127, 'target_x': 197}
# {'target_y': 183, 'me_x': 131, 'me_y': 127, 'target_x': 197}
# {'target_y': 198, 'me_x': 131, 'me_y': 132, 'target_x': 197}
# {'target_y': 183, 'me_x': 136, 'me_y': 132, 'target_x': 197}
# {'target_y': 198, 'me_x': 136, 'me_y': 137, 'target_x': 197}
# {'target_y': 183, 'me_x': 141, 'me_y': 137, 'target_x': 197}
# {'target_y': 198, 'me_x': 141, 'me_y': 142, 'target_x': 197}
# {'target_y': 183, 'me_x': 146, 'me_y': 142, 'target_x': 197}
# {'target_y': 198, 'me_x': 146, 'me_y': 147, 'target_x': 197}
# {'target_y': 183, 'me_x': 151, 'me_y': 147, 'target_x': 197}
# {'target_y': 198, 'me_x': 151, 'me_y': 152, 'target_x': 197}
# {'target_y': 183, 'me_x': 156, 'me_y': 152, 'target_x': 197}
# {'target_y': 198, 'me_x': 156, 'me_y': 157, 'target_x': 197}
# {'target_y': 183, 'me_x': 161, 'me_y': 157, 'target_x': 197}
# {'target_y': 198, 'me_x': 161, 'me_y': 162, 'target_x': 197}
# {'target_y': 183, 'me_x': 166, 'me_y': 162, 'target_x': 197}
# {'target_y': 198, 'me_x': 166, 'me_y': 167, 'target_x': 197}
# {'target_y': 183, 'me_x': 171, 'me_y': 167, 'target_x': 197}
# {'target_y': 198, 'me_x': 171, 'me_y': 172, 'target_x': 197}
# {'target_y': 183, 'me_x': 176, 'me_y': 172, 'target_x': 197}
# {'target_y': 198, 'me_x': 176, 'me_y': 177, 'target_x': 197}
# {'target_y': 183, 'me_x': 181, 'me_y': 177, 'target_x': 197}
# {'target_y': 198, 'me_x': 181, 'me_y': 182, 'target_x': 197}
# {'target_y': 183, 'me_x': 186, 'me_y': 182, 'target_x': 197}
# {'target_y': 198, 'me_x': 186, 'me_y': 187, 'target_x': 197}
# {'target_y': 183, 'me_x': 191, 'me_y': 187, 'target_x': 197}
# {'target_y': 168, 'me_x': 191, 'me_y': 182, 'target_x': 197}
# {'target_y': 153, 'me_x': 191, 'me_y': 177, 'target_x': 197}
# {'target_y': 138, 'me_x': 191, 'me_y': 172, 'target_x': 197}
# {'target_y': 123, 'me_x': 191, 'me_y': 167, 'target_x': 197}
# {'target_y': 108, 'me_x': 191, 'me_y': 162, 'target_x': 197}
# {'target_y': 93, 'me_x': 191, 'me_y': 157, 'target_x': 197}
# {'target_y': 78, 'me_x': 191, 'me_y': 152, 'target_x': 197}
# {'target_y': 63, 'me_x': 191, 'me_y': 147, 'target_x': 197}
# {'target_y': 48, 'me_x': 191, 'me_y': 142, 'target_x': 197}
# {'target_y': 33, 'me_x': 191, 'me_y': 137, 'target_x': 197}
# {'target_y': 18, 'me_x': 191, 'me_y': 132, 'target_x': 197}
# {'target_y': 3, 'me_x': 191, 'me_y': 127, 'target_x': 197}
# {'target_y': 3, 'me_x': 191, 'me_y': 122, 'target_x': 182}
# {'target_y': 3, 'me_x': 191, 'me_y': 117, 'target_x': 167}
# {'target_y': 3, 'me_x': 191, 'me_y': 112, 'target_x': 152}
# {'target_y': 3, 'me_x': 191, 'me_y': 107, 'target_x': 137}
# {'target_y': 3, 'me_x': 191, 'me_y': 102, 'target_x': 122}
# {'target_y': 3, 'me_x': 191, 'me_y': 97, 'target_x': 107}
# {'target_y': 3, 'me_x': 186, 'me_y': 97, 'target_x': 92}
# {'target_y': 3, 'me_x': 181, 'me_y': 97, 'target_x': 77}
# {'target_y': 3, 'me_x': 176, 'me_y': 97, 'target_x': 62}
# {'target_y': 3, 'me_x': 171, 'me_y': 97, 'target_x': 47}
# {'target_y': 3, 'me_x': 166, 'me_y': 97, 'target_x': 32}
# {'target_y': 3, 'me_x': 161, 'me_y': 97, 'target_x': 17}
# {'target_y': 3, 'me_x': 156, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 151, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 146, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 141, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 136, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 131, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 126, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 121, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 116, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 111, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 106, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 101, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 96, 'me_y': 97, 'target_x': 2}
# {'target_y': 18, 'me_x': 91, 'me_y': 97, 'target_x': 2}
# {'target_y': 3, 'me_x': 91, 'me_y': 92, 'target_x': 2}
# {'target_y': 18, 'me_x': 86, 'me_y': 92, 'target_x': 2}
# {'target_y': 3, 'me_x': 86, 'me_y': 87, 'target_x': 2}
# {'target_y': 18, 'me_x': 81, 'me_y': 87, 'target_x': 2}
# {'target_y': 3, 'me_x': 81, 'me_y': 82, 'target_x': 2}
# {'target_y': 18, 'me_x': 76, 'me_y': 82, 'target_x': 2}
# {'target_y': 3, 'me_x': 76, 'me_y': 77, 'target_x': 2}
# {'target_y': 18, 'me_x': 71, 'me_y': 77, 'target_x': 2}
# {'target_y': 3, 'me_x': 71, 'me_y': 72, 'target_x': 2}
# {'target_y': 18, 'me_x': 66, 'me_y': 72, 'target_x': 2}
# {'target_y': 3, 'me_x': 66, 'me_y': 67, 'target_x': 2}
# {'target_y': 18, 'me_x': 61, 'me_y': 67, 'target_x': 2}
# {'target_y': 3, 'me_x': 61, 'me_y': 62, 'target_x': 2}
# {'target_y': 18, 'me_x': 56, 'me_y': 62, 'target_x': 2}
# {'target_y': 3, 'me_x': 56, 'me_y': 57, 'target_x': 2}
# {'target_y': 18, 'me_x': 51, 'me_y': 57, 'target_x': 2}
# {'target_y': 3, 'me_x': 51, 'me_y': 52, 'target_x': 2}
# {'target_y': 18, 'me_x': 46, 'me_y': 52, 'target_x': 2}
# {'target_y': 3, 'me_x': 46, 'me_y': 47, 'target_x': 2}
# {'target_y': 18, 'me_x': 41, 'me_y': 47, 'target_x': 2}
# {'target_y': 3, 'me_x': 41, 'me_y': 42, 'target_x': 2}
# {'target_y': 18, 'me_x': 36, 'me_y': 42, 'target_x': 2}
# {'target_y': 3, 'me_x': 36, 'me_y': 37, 'target_x': 2}
# {'target_y': 18, 'me_x': 31, 'me_y': 37, 'target_x': 2}
# {'target_y': 3, 'me_x': 31, 'me_y': 32, 'target_x': 2}
# {'target_y': 18, 'me_x': 26, 'me_y': 32, 'target_x': 2}
# {'target_y': 3, 'me_x': 26, 'me_y': 27, 'target_x': 2}
# {'target_y': 18, 'me_x': 21, 'me_y': 27, 'target_x': 2}
# {'target_y': 3, 'me_x': 21, 'me_y': 22, 'target_x': 2}
# {'target_y': 18, 'me_x': 16, 'me_y': 22, 'target_x': 2}
# {'target_y': 3, 'me_x': 16, 'me_y': 17, 'target_x': 2}
# {'target_y': 18, 'me_x': 11, 'me_y': 17, 'target_x': 2}
# {'target_y': 33, 'me_x': 11, 'me_y': 22, 'target_x': 2}
# {'target_y': 48, 'me_x': 11, 'me_y': 27, 'target_x': 2}
# {'target_y': 63, 'me_x': 11, 'me_y': 32, 'target_x': 2}
# {'target_y': 78, 'me_x': 11, 'me_y': 37, 'target_x': 2}
# {'target_y': 93, 'me_x': 11, 'me_y': 42, 'target_x': 2}
# {'target_y': 108, 'me_x': 11, 'me_y': 47, 'target_x': 2}
# {'target_y': 123, 'me_x': 11, 'me_y': 52, 'target_x': 2}
# {'target_y': 138, 'me_x': 11, 'me_y': 57, 'target_x': 2}
# {'target_y': 153, 'me_x': 11, 'me_y': 62, 'target_x': 2}
# {'target_y': 168, 'me_x': 11, 'me_y': 67, 'target_x': 2}
# {'target_y': 183, 'me_x': 11, 'me_y': 72, 'target_x': 2}
# {'target_y': 198, 'me_x': 11, 'me_y': 77, 'target_x': 2}
# {'target_y': 198, 'me_x': 11, 'me_y': 82, 'target_x': 17}
# {'target_y': 198, 'me_x': 11, 'me_y': 87, 'target_x': 32}
# {'target_y': 198, 'me_x': 11, 'me_y': 92, 'target_x': 47}
